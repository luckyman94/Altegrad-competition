# %%
import sys
import os
import sys
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool
import pickle
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm
from torch.utils.data import DataLoader


from data_utils import PreprocessedGraphDataset, load_descriptions_from_graphs,load_id2emb, collate_fn
from inspect_graph_data import inspect_graph_file
import retrieval_answer
import train_gcn

# %%
TRAIN_GRAPHS = "data/train_graphs.pkl"
TEST_GRAPHS = "data/test_graphs.pkl"
VAL_GRAPHS = "data_baseline/data/validation_graphs.pkl"
OUTPUT_DIR = ""
TRAIN_EMB_CSV = "train_embeddings.csv"
VAL_EMB_CSV = "validation_embeddings.csv"

# Train_gcn_paths
train_gcn.TRAIN_GRAPHS = TRAIN_GRAPHS
train_gcn.VAL_GRAPHS   = VAL_GRAPHS
train_gcn.TEST_GRAPHS  = TEST_GRAPHS
train_gcn.TRAIN_EMB_CSV = TRAIN_EMB_CSV
train_gcn.VAL_EMB_CSV   = VAL_EMB_CSV

# Retrieval answers paths
retrieval_answer.TRAIN_GRAPHS = TRAIN_GRAPHS
retrieval_answer.VAL_GRAPHS   = VAL_GRAPHS
retrieval_answer.TEST_GRAPHS  = TEST_GRAPHS
retrieval_answer.TRAIN_EMB_CSV = TRAIN_EMB_CSV
retrieval_answer.VAL_EMB_CSV   = VAL_EMB_CSV

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu
